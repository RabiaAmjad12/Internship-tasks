# %% [markdown]
# <a href="https://colab.research.google.com/github/RabiaAmjad12/Internship-tasks/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv("iris.csv")
df.head(150)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# shape of the dataframe
df.shape
# Out:
# (150, 6)

# %%
# columns of the dataframe
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# histogram (sepal length distributin)
plt.figure(figsize=(8,6))
sns.histplot(data=df, x="SepalLengthCm",  kde=True, bins=20, color="red")
plt.title("Distribution of sepal length")
plt.xlabel("sepal length (cm)")
plt.ylabel("frequency")
plt.show()

# %%
# BOX PLOT petal width
plt.figure(figsize=(8,6))
sns.boxplot(data=df, x="Species", y="PetalWidthCm", color="green")
plt.title("Box plot of petal width")
plt.xlabel("species")
plt.ylabel("petal width (cm)")
plt.show()

# %%
# scatter plot sepal length vs petal length
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="SepalLengthCm", y="PetalLengthCm", hue="Species", palette="Set1")
plt.title("scatter plot of sepal length vs petal length")
plt.xlabel("sepal length (cm)")
plt.ylabel("petal length (cm)")
plt.show()
